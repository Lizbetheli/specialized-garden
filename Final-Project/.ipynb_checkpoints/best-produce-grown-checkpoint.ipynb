# %%
from bs4 import BeautifulSoup
from splinter import Browser
import pandas as pd
import os
import time
import requests

# %%
executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = "https://www.purewow.com/food/best-produce-grown-in-every-state"
browser.visit(url)
time.sleep(1)

# %%
# Retrieve page with the requests module
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')
print(response.text)
# Out:
# <!DOCTYPE html>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <html lang="en-US">
#
# <head>
#
#
#
#
#
# 		<!-- OneTrust Cookies Consent Notice start -->
# 		<script src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript" charset="UTF-8" data-domain-script="c750a38d-7fd2-40ef-a577-5adc247540e0"></script>
# 		<script type="text/javascript">function OptanonWrapper(){}</script>
# 		<!-- OneTrust Cookies Consent Notice end -->
#
#
#
# 	<script src="https://cdn.cookielaw.org/opt-out/otCCPAiab.js" type="text/javascript" charset="UTF-8" ccpa-opt-out-ids="C0004" ccpa-opt-out-geo="ca" ccpa-opt-out-lspa="true"></script>
#
#
#
#
#
# <!-- f: multipart_detail (national : 7/4371) -->
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
#html = browser.html
results = soup.find_all('div', id='element_40464')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    blackberries = result.find('img',alt='blackberries')
    print(blackberries.get('src'))
    
    
    # scrape the article subheader
    Alabama = result.find('h2',class_='firsth2').text
    
    # print article data
    #print('-----------------')
    #print(Blackberries)
    print(Alabama)
    #print(result)
    #print(results)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/blackberries.png?auto=format,compress&cs=strip
# Alabama: Blackberries

# %%
results = soup.find_all('div', id='element_40465')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    cabage = result.find('img',alt='cabage')
    print(cabage.get('data-src'))
    
    
    # scrape the article subheader
    Alaska = result.find('h2',class_='firsth2').text
    
    # print article data
    #print('-----------------')
    #print(cabage)
    print(Alaska)
    #print(result)
    #print(results)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/cabage.png?auto=format,compress&cs=strip
# Alaska: Cabbage

# %%
results = soup.find_all('div', id='element_40466')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    melon = result.find('img',alt='melon')
    print(melon.get('data-src'))
    
    
    # scrape the article subheader
    Arkansas = result.find('h2',class_='firsth2').text

    #print(watermelon)
    print(Arkansas)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/melon.png?auto=format,compress&cs=strip
# Arkansas: Watermelon

# %%
results = soup.find_all('div', id='element_40467')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    lettuce = result.find('img',alt='lettuce')
    print(lettuce.get('data-src'))
    
    
    # scrape the article subheader
    Arizona = result.find('h2',class_='firsth2').text

    print(Arizona)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/lettuce.png?auto=format,compress&cs=strip
# Arizona: Lettuce

# %%
results = soup.find_all('div', id='element_40468')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    california = result.find('img',alt='california')
    print(california.get('data-src'))
    
    
    # scrape the article subheader
    Avocados = result.find('h2',class_='firsth2').text

    print(Avocados)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/california.png?auto=format,compress&cs=strip
# California: Avocados

# %%
results = soup.find_all('div', id='element_40469')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    marijuana = result.find('img',alt='marijuana')
    print(marijuana.get('data-src'))
    
    
    # scrape the article subheader
    Colorado = result.find('h2',class_='firsth2').text

    print(Colorado)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/marijuana.png?auto=format,compress&cs=strip
# Colorado: Marijuana

# %%
results = soup.find_all('div', id='element_40470')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    conn = result.find('img',alt='conn')
    print(conn.get('data-src'))
    
    
    # scrape the article subheader
    Connecticut = result.find('h2',class_='firsth2').text

    print(Connecticut)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/conn.png?auto=format,compress&cs=strip
# Connecticut: Asian Pears

# %%
results = soup.find_all('div', id='element_40471')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    delaware = result.find('img',alt='delaware')
    print(delaware.get('data-src'))
    
    
    # scrape the article subheader
    Strawberries = result.find('h2',class_='firsth2').text

    print(Strawberries)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/delaware.png?auto=format,compress&cs=strip
# Delaware: Strawberries

# %%
results = soup.find_all('div', id='element_40472')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    florida = result.find('img',alt='florida')
    print(florida.get('data-src'))
    
    
    # scrape the article subheader
    Oranges = result.find('h2',class_='firsth2').text
    
    print(Oranges)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/florida.png?auto=format,compress&cs=strip
# Florida: Honeybell Oranges

# %%
results = soup.find_all('div', id='element_40473')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    georgia = result.find('img',alt='georgia')
    print(georgia.get('data-src'))
    
    
    # scrape the article subheader
    Peaches = result.find('h2',class_='firsth2').text
    
    print(Peaches)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/georgia.png?auto=format,compress&cs=strip
# Georgia: Peaches

# %%
results = soup.find_all('div', id='element_40474')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    pineapple = result.find('img',alt='pineapple')
    print(pineapple.get('data-src'))
    
    
    # scrape the article subheader
    Hawaii = result.find('h2',class_='firsth2').text
    
    print(Hawaii)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/pineapple.png?auto=format,compress&cs=strip
# Hawaii: Pineapple

# %%
results = soup.find_all('div', id='element_40475')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    idah = result.find('img',alt='idah')
    print(idah.get('data-src'))
    
    
    # scrape the article subheader
    Idaho = result.find('h2',class_='firsth2').text
    
    print(Idaho)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/idah.png?auto=format,compress&cs=strip
# Idaho: Russet Potatoes

# %%
results = soup.find_all('div', id='element_40476')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    soybean = result.find('img',alt='soybean')
    print(soybean.get('data-src'))
    
    
    # scrape the article subheader
    Illinois = result.find('h2',class_='firsth2').text
    
    print(Illinois)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/soybean.png?auto=format,compress&cs=strip
# Illinois: Soybeans

# %%
results = soup.find_all('div', id='element_40477')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    corn = result.find('img',alt='corn')
    print(corn.get('data-src'))
    
    
    # scrape the article subheader
    Iowa = result.find('h2',class_='firsth2').text
    
    print(Iowa)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/corn.png?auto=format,compress&cs=strip
# Iowa: Corn

# %%
results = soup.find_all('div', id='element_40478')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    wheat = result.find('img',alt='wheat')
    print(wheat.get('data-src'))
    
    
    # scrape the article subheader
    Indiana = result.find('h2',class_='firsth2').text
    
    print(Indiana)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/wheat.png?auto=format,compress&cs=strip
# Indiana: Winter Wheat

# %%
results = soup.find_all('div', id='element_40479')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    kansas = result.find('img',alt='kansas')
    print(kansas.get('data-src'))
    
    
    # scrape the article subheader
    Sorghum = result.find('h2',class_='firsth2').text
    
    print(Sorghum)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/kansas.png?auto=format,compress&cs=strip
# Kansas: Sorghum

# %%
results = soup.find_all('div', id='element_40480')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    louisianna = result.find('img',alt='louisianna')
    print(louisianna.get('data-src'))
    
    
    # scrape the article subheader
    Sugarcane = result.find('h2',class_='firsth2').text
    
    print(Sugarcane)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/louisianna.png?auto=format,compress&cs=strip
# Louisiana: Sugarcane

# %%
results = soup.find_all('div', id='element_40481')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    blueberry = result.find('img',alt='blueberry')
    print(blueberry.get('data-src'))
    
    
    # scrape the article subheader
    Maine = result.find('h2',class_='firsth2').text
    
    print(Maine)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/blueberry.png?auto=format,compress&cs=strip
# Maine: Blueberries

# %%
results = soup.find_all('div', id='element_40482')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    crabs = result.find('img',alt='crabs')
    print(crabs.get('data-src'))
    
    
    # scrape the article subheader
    Maryland = result.find('h2',class_='firsth2').text
    
    print(Maryland)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/crabs.png?auto=format,compress&cs=strip
# Maryland: Crabs

# %%
results = soup.find_all('div', id='element_40483')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    mass = result.find('img',alt='mass')
    print(mass.get('data-src'))
    
    
    # scrape the article subheader
    Cranberries = result.find('h2',class_='firsth2').text
    
    print(Cranberries)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/mass.png?auto=format,compress&cs=strip
# Massachusetts: Cranberries

# %%
results = soup.find_all('div', id='element_40484')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    michigan = result.find('img',alt='michigan')
    print(michigan.get('data-src'))
    
    
    # scrape the article subheader
    Cherries = result.find('h2',class_='firsth2').text
    
    print(Cherries)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/michigan.png?auto=format,compress&cs=strip
# Michigan: Cherries

# %%
results = soup.find_all('div', id='element_40485')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    minnesota = result.find('img',alt='minnesota')
    print(minnesota.get('data-src'))
    
    
    # scrape the article subheader
    Apples = result.find('h2',class_='firsth2').text
    
    print(Apples)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/minnesota.png?auto=format,compress&cs=strip
# Minnesota: Honeycrisp Apples

# %%
results = soup.find_all('div', id='element_40486')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    maize = result.find('img',alt='maize')
    print(maize.get('data-src'))
    
    
    # scrape the article subheader
    Mississippi = result.find('h2',class_='firsth2').text
    
    print(Mississippi)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/maize.png?auto=format,compress&cs=strip
# Mississippi: Maize

# %%
results = soup.find_all('div', id='element_40487')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    missouri = result.find('img',alt='missouri')
    print(missouri.get('data-src'))
    
    
    # scrape the article subheader
    Hay = result.find('h2',class_='firsth2').text
    
    print(Hay)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/missouri.png?auto=format,compress&cs=strip
# Missouri:  Hay

# %%
results = soup.find_all('div', id='element_40488')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    beans = result.find('img',alt='beans')
    print(beans.get('data-src'))
    
    
    # scrape the article subheader
    Montana = result.find('h2',class_='firsth2').text
    
    print(Montana)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/beans.png?auto=format,compress&cs=strip
# Montana: Beans

# %%
results = soup.find_all('div', id='element_40489')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    sugarbeet = result.find('img',alt='sugarbeet')
    print(sugarbeet.get('data-src'))
    
    
    # scrape the article subheader
    Nebraska = result.find('h2',class_='firsth2').text
    
    print(Nebraska)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/sugarbeet.png?auto=format,compress&cs=strip
# Nebraska: Sugar beets

# %%
results = soup.find_all('div', id='element_40490')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    alflfa = result.find('img',alt='alflfa')
    print(alflfa.get('data-src'))
    
    
    # scrape the article subheader
    Nevada = result.find('h2',class_='firsth2').text
    
    print(Nevada)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/alflfa.png?auto=format,compress&cs=strip
# Nevada: Alfalfa Seed

# %%
results = soup.find_all('div', id='element_40491')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    pumpkin = result.find('img',alt='pumpkin')
    print(pumpkin.get('data-src'))
    
    
    # scrape the article subheader
    New = result.find('h2',class_='firsth2').text
    
    print(New)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/pumpkin.png?auto=format,compress&cs=strip
# New Hampshire: Pumpkins

# %%
results = soup.find_all('div', id='element_40492')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    tomatoes = result.find('img',alt='tomatoes')
    print(tomatoes.get('data-src'))
    
    
    # scrape the article subheader
    Jersey = result.find('h2',class_='firsth2').text
    
    print(Jersey)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/tomatoes.png?auto=format,compress&cs=strip
# New Jersey: Tomatoes

# %%
results = soup.find_all('div', id='element_40493')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    newmexico = result.find('img',alt='newmexico')
    print(newmexico.get('data-src'))
    
    
    # scrape the article subheader
    Peppers = result.find('h2',class_='firsth2').text
    
    print(Peppers)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/newmexico.png?auto=format,compress&cs=strip
# New Mexico: GREEN CHILE PEPPERS

# %%
results = soup.find_all('div', id='element_40494')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    apple = result.find('img',alt='apple')
    print(apple.get('data-src'))
    
    
    # scrape the article subheader
    Newyork = result.find('h2',class_='firsth2').text
    
    print(Newyork)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/apple.png?auto=format,compress&cs=strip
# NEW YORK: CORTLAND APPLES

# %%
results = soup.find_all('div', id='element_40495')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    northcarolina = result.find('img',alt='northcarolina')
    print(northcarolina.get('data-src'))
    
    
    # scrape the article subheader
    Potatoes = result.find('h2',class_='firsth2').text
    
    print(Potatoes)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/northcarolina.png?auto=format,compress&cs=strip
# NORTH CAROLINA: SWEET POTATOES

# %%
results = soup.find_all('div', id='element_40496')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    sunflowers = result.find('img',alt='sunflowers')
    print(sunflowers.get('data-src'))
    
    
    # scrape the article subheader
    NorthD = result.find('h2',class_='firsth2').text
    
    print(NorthD)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/sunflowers.png?auto=format,compress&cs=strip
# North Dakota: Sunflowers

# %%
results = soup.find_all('div', id='element_40497')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    ohio = result.find('img',alt='ohio')
    print(ohio.get('data-src'))
    
    
    # scrape the article subheader
    Pawpaw = result.find('h2',class_='firsth2').text
    
    print(Pawpaw)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/ohio.png?auto=format,compress&cs=strip
# Ohio: Pawpaw

# %%
results = soup.find_all('div', id='element_40498')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    peanuts = result.find('img',alt='peanuts')
    print(peanuts.get('data-src'))
    
    
    # scrape the article subheader
    Oklahoma = result.find('h2',class_='firsth2').text
    
    print(Oklahoma)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/peanuts.png?auto=format,compress&cs=strip
# Oklahoma: Peanuts

# %%
results = soup.find_all('div', id='element_40499')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    hops = result.find('img',alt='hops')
    print(hops.get('data-src'))
    
    
    # scrape the article subheader
    Oregon = result.find('h2',class_='firsth2').text
    
    print(Oregon)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/hops.png?auto=format,compress&cs=strip
# Oregon: Hops

# %%
results = soup.find_all('div', id='element_40500')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    shroom = result.find('img',alt='shroom')
    print(shroom.get('data-src'))
    
    
    # scrape the article subheader
    Pennsylvania = result.find('h2',class_='firsth2').text
    
    print(Pennsylvania)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/shroom.png?auto=format,compress&cs=strip
# Pennsylvania: Mushrooms

# %%
results = soup.find_all('div', id='element_40501')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    rhodeisland = result.find('img',alt='rhodeisland')
    print(rhodeisland.get('data-src'))
    
    
    # scrape the article subheader
    RIgreening = result.find('h2',class_='firsth2').text
    
    print(RIgreening)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/rhodeisland.png?auto=format,compress&cs=strip
# Rhode Island: RI Greening Apples

# %%
results = soup.find_all('div', id='element_40502')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    collard = result.find('img',alt='collard')
    print(collard.get('data-src'))
    
    
    # scrape the article subheader
    SCarolina = result.find('h2',class_='firsth2').text
    
    print(SCarolina)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/collard.png?auto=format,compress&cs=strip
# South Carolina: Collard Greens

# %%
results = soup.find_all('div', id='element_40503')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    slaxseed = result.find('img',alt='slaxseed')
    print(slaxseed.get('data-src'))
    
    
    # scrape the article subheader
    SDakota = result.find('h2',class_='firsth2').text
    
    print(SDakota)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/slaxseed.png?auto=format,compress&cs=strip
# South Dakota: Flaxseed

# %%
results = soup.find_all('div', id='element_40504')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    whiskey = result.find('img',alt='whiskey')
    print(whiskey.get('data-src'))
    
    
    # scrape the article subheader
    Tennessee = result.find('h2',class_='firsth2').text
    
    print(Tennessee)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/whiskey.png?auto=format,compress&cs=strip
# Tennessee: Jack Daniel's Whiskey

# %%
results = soup.find_all('div', id='element_40505')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    pean = result.find('img',alt='pean')
    print(pean.get('data-src'))
    
    
    # scrape the article subheader
    Texas = result.find('h2',class_='firsth2').text
    
    print(Texas)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/pean.png?auto=format,compress&cs=strip
# Texas: Pecans

# %%
results = soup.find_all('div', id='element_40506')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    barley = result.find('img',alt='barley')
    print(barley.get('data-src'))
    
    
    # scrape the article subheader
    Utah = result.find('h2',class_='firsth2').text
    
    print(Utah)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/barley.png?auto=format,compress&cs=strip
# Utah: Barley

# %%
results = soup.find_all('div', id='element_40507')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    syrup = result.find('img',alt='syrup')
    print(syrup.get('data-src'))
    
    
    # scrape the article subheader
    Vermont = result.find('h2',class_='firsth2').text
    
    print(Vermont)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/syrup.png?auto=format,compress&cs=strip
# Vermont: Maple Syrup

# %%
results = soup.find_all('div', id='element_40508')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    grapes = result.find('img',alt='grapes')
    print(grapes.get('data-src'))
    
    
    # scrape the article subheader
    Virginia = result.find('h2',class_='firsth2').text
    
    print(Virginia)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/grapes.png?auto=format,compress&cs=strip
# Virginia: Grapes

# %%
results = soup.find_all('div', id='element_40509')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    apple1 = result.find('img',alt='apple1')
    print(apple1.get('data-src'))
    
    
    # scrape the article subheader
    Washington = result.find('h2',class_='firsth2').text
    
    print(Washington)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/apple1.png?auto=format,compress&cs=strip
# Washington: Apples

# %%
results = soup.find_all('div', id='element_40510')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    golden = result.find('img',alt='golden')
    print(golden.get('data-src'))
    
    
    # scrape the article subheader
    WVirginia = result.find('h2',class_='firsth2').text
    
    print(WVirginia)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/golden.png?auto=format,compress&cs=strip
# West Virginia: Golden Delicious Apples

# %%
results = soup.find_all('div', id='element_40511')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    corn1 = result.find('img',alt='corn1')
    print(corn1.get('data-src'))
    
    
    # scrape the article subheader
    Wisconsin = result.find('h2',class_='firsth2').text
    
    print(Wisconsin)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/corn1.png?auto=format,compress&cs=strip
# Wisconsin: Sweet Corn

# %%
results = soup.find_all('div', id='element_40512')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    cow = result.find('img',alt='cow')
    print(cow.get('data-src'))
    
    
    # scrape the article subheader
    Wyoming = result.find('h2',class_='firsth2').text
    
    print(Wyoming)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/cow.png?auto=format,compress&cs=strip
# Wyoming: Livestock

# %%
results = soup.find_all('div', id='element_40513')
#print(results)

# %%
# loop over results to get article data
for result in results:
    # scrape the article header
    #print(result)
    bourbon = result.find('img',alt='bourbon')
    print(bourbon.get('data-src'))
    
    
    # scrape the article subheader
    Kentucky = result.find('h2',class_='firsth2').text
    
    print(Kentucky)
# Out:
# https://purewows3.imgix.net/images/articles/2016_10/bourbon.png?auto=format,compress&cs=strip
# Kentucky: Bourbon

# %%
Kentucky
# Out:
# 'Kentucky: Bourbon'

# %%
bourbon.get('data-src')
# Out:
# 'https://purewows3.imgix.net/images/articles/2016_10/bourbon.png?auto=format,compress&cs=strip'

# %%
#Summary Table
summary={
    'Kentucky' : [Kentucky],
    'Wyoming' : [Wyoming],
    'Wisconsin' : [Wisconsin],
    'WVirginia' : [WVirginia],
    'Washington' : [Washington],
    'Virginia' : [Virginia],
    'Vermont' : [Vermont],
    'Utah' : [Utah],
    'Texas' : [Texas],
    'Tennessee' : [Tennessee],
    'SDakota' : [SDakota],
    'SCarolina' : [SCarolina],
    'RIgreening' : [RIgreening],
    'Pennsylvania' : [Pennsylvania],
    'Oregon' : [Oregon],
    'Oklahoma' : [Oklahoma],
    'Pawpaw' : [Pawpaw],
    'NorthD' : [NorthD],
    'Potatoes' : [Potatoes],
    'Newyork' : [Newyork],
    'Peppers' : [Peppers],
    'Jersey' : [Jersey],
    'New' : [New],
    'Nevada' : [Nevada],
    'Nebraska' : [Nebraska],
    'Montana' : [Montana],
    'Hay' : [Hay],
    'Mississippi' : [Mississippi],
    'Apples' : [Apples],
    'Cherries' : [Cherries],
    'Cranberries' : [Cranberries],
    'Maryland' : [Maryland],
    'Maine' : [Maine],
    'Sugarcane' : [Sugarcane],
    'Sorghum' : [Sorghum],
    'Indiana' : [Indiana],
    'Iowa' : [Iowa],
    'Illinois' : [Illinois],
    'Idaho' : [Idaho],
    'Hawaii' : [Hawaii],
    'Peaches' : [Peaches],
    'Oranges' : [Oranges],
    'Strawberries' : [Strawberries],
    'Connecticut' : [Connecticut],
    'Colorado' : [Colorado],
    'Avocados' : [Avocados],
    'Arizona' : [Arizona],
    'Arkansas' : [Arkansas],
    'Alaska' : [Alaska]
}
summary_df=pd.DataFrame(summary)
summary_df
# Out:
#             Kentucky             Wyoming              Wisconsin  \
# 0  Kentucky: Bourbon  Wyoming: Livestock  Wisconsin: Sweet Corn
#
#                                 WVirginia          Washington  \
# 0  West Virginia: Golden Delicious Apples  Washington: Apples
#
#            Virginia               Vermont          Utah           Texas  \
# 0  Virginia: Grapes  Vermont: Maple Syrup  Utah: Barley  Texas: Pecans
#
#                           Tennessee  ...             Hawaii           Peaches  \
# 0  Tennessee: Jack Daniel's Whiskey  ...  Hawaii: Pineapple  Georgia: Peaches
#
#                       Oranges            Strawberries  \
# 0  Florida: Honeybell Oranges  Delaware: Strawberries
#
#                 Connecticut             Colorado              Avocados  \
# 0  Connecticut: Asian Pears  Colorado: Marijuana  California: Avocados
#
#             Arizona              Arkansas            Alaska
# 0  Arizona: Lettuce  Arkansas: Watermelon  Alaska: Cabbage
#
# ...
